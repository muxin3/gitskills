# %% [markdown]
# <a href="https://colab.research.google.com/github/muxin3/gitskills/blob/main/CIFAR100_with_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

# %%
import torch
import torchvision
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.autograd import Variable

# %%
# !mkdir models
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %%
batch_size = 64
learning_rate = 3e-3
num_epochs = 20

# %%
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.5.1+cu121
# 0.20.1+cu121

# %%
data_transforms = {
    'train':
    transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ]),
    'test':
    transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
    ]),
}

# %%
data_sets = {
    'train': torchvision.datasets.CIFAR100(root='data', train=True, download=True, transform=data_transforms['train']),
    'test': torchvision.datasets.CIFAR100(root='data', download=True, transform=data_transforms['test'])
}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(data_sets['train'])
print('='*85)
print(data_sets['test'])
# Out:
# Dataset CIFAR100
#     Number of datapoints: 50000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )
# =====================================================================================
# Dataset CIFAR100
#     Number of datapoints: 50000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %%
dataloaders = {
    'train':
    torch.utils.data.DataLoader(data_sets['train'],
                                batch_size=batch_size,
                                shuffle=True,
                                num_workers=0),
    'test':
    torch.utils.data.DataLoader(data_sets['test'],
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=0)
}

# %%
use_cuda = torch.cuda.is_available()

device = torch.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# cuda:0

# %%
model = models.resnet50(pretrained=True)

model = model.cuda() if use_cuda else model

num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 1024)
model.fc = nn.Sequential(
    torch.nn.Dropout(0.5),
    torch.nn.Linear(num_ftrs, 1024),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(1024, 512),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(512, 256),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(256, 128),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(128, len(data_sets['train'].classes))
)

model.fc = model.fc.cuda() if use_cuda else model.fc

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
train_acces, test_acces = [], []
train_losses, test_losses = [], []
total_step = len(dataloaders['train'])
test_loss_min = np.Inf
for epoch in range(num_epochs):
    print(f'Epoch {epoch}\n')

    network_learned = False

    for phase in ['train', 'test']:

        running_loss = 0.0
        running_corrects = 0

        if phase == 'train':
            model.train()

            for batch_idx, (inputs, labels) in enumerate(dataloaders[phase]):

                if use_cuda:
                    inputs = Variable(inputs.cuda())
                    labels = Variable(labels.cuda())
                else:
                    inputs, labels = Variable(inputs), Variable(labels)

                inputs = inputs.float()
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item()
                running_corrects += torch.sum(preds == labels.data)
                if (batch_idx) % 20 == 0:
                    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch, num_epochs-1, batch_idx, total_step, loss.item()))
            scheduler.step()
        else:
            with torch.no_grad():
                model.eval()
                for inputs, labels in dataloaders[phase]:
                    if use_cuda:
                        inputs = Variable(inputs.cuda())
                        labels = Variable(labels.cuda())
                    else:
                        inputs, labels = Variable(inputs), Variable(labels)

                    inputs = inputs.float()
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)
                    running_loss += loss.item()
                    running_corrects += torch.sum(preds == labels.data)
            network_learned = running_loss < test_loss_min
            test_loss_min = running_loss if network_learned else test_loss_min


        epoch_loss = running_loss / len(data_sets[phase])
        epoch_acc = running_corrects.double() / len(data_sets[phase])

        if phase == 'train':
            train_acces.append(epoch_acc * 100)
            train_losses.append(epoch_loss)
        else:
            test_acces.append(epoch_acc * 100)
            test_losses.append(epoch_loss)
    print(f'\ntrain-loss: {np.mean(train_losses):.4f}, train-acc: {train_acces[-1]:.4f}')
    print(f'test loss: {np.mean(test_losses):.4f}, test acc: {test_acces[-1]:.4f}\n')

    if network_learned:
        torch.save(model.state_dict(), 'models/weights.h5')
        print('Improvement-Detected, save-model')
# Out:
# Epoch 0
#
# Epoch [0/19], Step [0/782], Loss: 4.6283
# Epoch [0/19], Step [20/782], Loss: 4.6231
# Epoch [0/19], Step [40/782], Loss: 4.5764
# Epoch [0/19], Step [60/782], Loss: 4.6228
# Epoch [0/19], Step [80/782], Loss: 4.5800
# Epoch [0/19], Step [100/782], Loss: 4.5546
# Epoch [0/19], Step [120/782], Loss: 4.5306
# Epoch [0/19], Step [140/782], Loss: 4.5341
# Epoch [0/19], Step [160/782], Loss: 4.4620
# Epoch [0/19], Step [180/782], Loss: 4.3802
# Epoch [0/19], Step [200/782], Loss: 4.3539
# Epoch [0/19], Step [220/782], Loss: 4.2967
# Epoch [0/19], Step [240/782], Loss: 4.1798
# Epoch [0/19], Step [260/782], Loss: 4.1018
# Epoch [0/19], Step [280/782], Loss: 3.8067
# Epoch [0/19], Step [300/782], Loss: 4.0132
# Epoch [0/19], Step [320/782], Loss: 3.6900
# Epoch [0/19], Step [340/782], Loss: 3.3516
# Epoch [0/19], Step [360/782], Loss: 3.7226
# Epoch [0/19], Step [380/782], Loss: 3.5164
# Epoch [0/19], Step [400/782], Loss: 3.4403
# Epoch [0/19], Step [420/782], Loss: 3.3053
# Epoch [0/19], Step [440/782], Loss: 3.5002
# Epoch [0/19], Step [460/782], Loss: 3.3943
# Epoch [0/19], Step [480/782], Loss: 3.0325
# Epoch [0/19], Step [500/782], Loss: 3.3365
# Epoch [0/19], Step [520/782], Loss: 3.1445
# Epoch [0/19], Step [540/782], Loss: 2.6705
# Epoch [0/19], Step [560/782], Loss: 3.0241
# Epoch [0/19], Step [580/782], Loss: 2.9355
# Epoch [0/19], Step [600/782], Loss: 2.9737
# Epoch [0/19], Step [620/782], Loss: 2.7974
# Epoch [0/19], Step [640/782], Loss: 2.6217
# Epoch [0/19], Step [660/782], Loss: 2.8032
# Epoch [0/19], Step [680/782], Loss: 2.7505
# Epoch [0/19], Step [700/782], Loss: 3.0964
# Epoch [0/19], Step [720/782], Loss: 2.5424
# Epoch [0/19], Step [740/782], Loss: 2.9889
# Epoch [0/19], Step [760/782], Loss: 2.7802
# Epoch [0/19], Step [780/782], Loss: 2.6483
#
# train-loss: 0.0567, train-acc: 14.6020
# test loss: 0.0373, test acc: 36.3220
#
# Improvement-Detected, save-model
# Epoch 1
#
# Epoch [1/19], Step [0/782], Loss: 2.5877
# Epoch [1/19], Step [20/782], Loss: 2.5470
# Epoch [1/19], Step [40/782], Loss: 2.3716
# Epoch [1/19], Step [60/782], Loss: 2.7337
# Epoch [1/19], Step [80/782], Loss: 2.3232
# Epoch [1/19], Step [100/782], Loss: 2.1831
# Epoch [1/19], Step [120/782], Loss: 2.5190
# Epoch [1/19], Step [140/782], Loss: 2.2410
# Epoch [1/19], Step [160/782], Loss: 2.3237
# Epoch [1/19], Step [180/782], Loss: 2.4389
# Epoch [1/19], Step [200/782], Loss: 2.5466
# Epoch [1/19], Step [220/782], Loss: 2.3468
# Epoch [1/19], Step [240/782], Loss: 2.0219
# Epoch [1/19], Step [260/782], Loss: 2.1547
# Epoch [1/19], Step [280/782], Loss: 2.0727
# Epoch [1/19], Step [300/782], Loss: 2.4468
# Epoch [1/19], Step [320/782], Loss: 2.4301
# Epoch [1/19], Step [340/782], Loss: 3.2002
# Epoch [1/19], Step [360/782], Loss: 2.4774
# Epoch [1/19], Step [380/782], Loss: 2.5696
# Epoch [1/19], Step [400/782], Loss: 2.3678
# Epoch [1/19], Step [420/782], Loss: 1.9189
# Epoch [1/19], Step [440/782], Loss: 2.1860
# Epoch [1/19], Step [460/782], Loss: 2.3876
# Epoch [1/19], Step [480/782], Loss: 2.0909
# Epoch [1/19], Step [500/782], Loss: 2.3374
# Epoch [1/19], Step [520/782], Loss: 2.1259
# Epoch [1/19], Step [540/782], Loss: 2.5294
# Epoch [1/19], Step [560/782], Loss: 2.5047
# Epoch [1/19], Step [580/782], Loss: 2.3314
# Epoch [1/19], Step [600/782], Loss: 2.4818
# Epoch [1/19], Step [620/782], Loss: 2.2345
# Epoch [1/19], Step [640/782], Loss: 2.2954
# Epoch [1/19], Step [660/782], Loss: 1.9473
# Epoch [1/19], Step [680/782], Loss: 2.3614
# Epoch [1/19], Step [700/782], Loss: 2.3383
# Epoch [1/19], Step [720/782], Loss: 2.2054
# Epoch [1/19], Step [740/782], Loss: 2.0202
# Epoch [1/19], Step [760/782], Loss: 1.9345
# Epoch [1/19], Step [780/782], Loss: 2.1768
#
# train-loss: 0.0463, train-acc: 39.4840
# test loss: 0.0320, test acc: 53.1600
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/19], Step [0/782], Loss: 1.9065
# Epoch [2/19], Step [20/782], Loss: 1.9231
# Epoch [3/19], Step [340/782], Loss: 1.6973
# Epoch [3/19], Step [360/782], Loss: 1.8688
# Epoch [3/19], Step [380/782], Loss: 1.6913
# Epoch [3/19], Step [400/782], Loss: 1.9328
# Epoch [3/19], Step [420/782], Loss: 1.9558
# Epoch [3/19], Step [440/782], Loss: 1.3707
# Epoch [3/19], Step [460/782], Loss: 1.6007
# Epoch [3/19], Step [480/782], Loss: 1.5032
# Epoch [3/19], Step [500/782], Loss: 1.8247
# Epoch [3/19], Step [520/782], Loss: 1.9562
# Epoch [3/19], Step [540/782], Loss: 1.5535
# Epoch [3/19], Step [560/782], Loss: 1.8091
# Epoch [3/19], Step [580/782], Loss: 1.6918
# Epoch [3/19], Step [600/782], Loss: 1.6620
# Epoch [3/19], Step [620/782], Loss: 1.5217
# Epoch [3/19], Step [640/782], Loss: 1.7225
# Epoch [3/19], Step [660/782], Loss: 1.6343
# Epoch [3/19], Step [680/782], Loss: 1.9342
# Epoch [3/19], Step [700/782], Loss: 1.8449
# Epoch [3/19], Step [720/782], Loss: 1.9016
# Epoch [3/19], Step [740/782], Loss: 1.3630
# Epoch [3/19], Step [760/782], Loss: 1.6787
# Epoch [3/19], Step [780/782], Loss: 1.5170
#
# train-loss: 0.0370, train-acc: 55.1360
# test loss: 0.0264, test acc: 65.1800
#
# Improvement-Detected, save-model
# Epoch 4
#
# Epoch [4/19], Step [0/782], Loss: 1.7239
# Epoch [4/19], Step [20/782], Loss: 1.7600
# Epoch [4/19], Step [40/782], Loss: 1.6903
# Epoch [4/19], Step [60/782], Loss: 1.3014
# Epoch [4/19], Step [80/782], Loss: 1.3225
# Epoch [4/19], Step [100/782], Loss: 1.2524
# Epoch [4/19], Step [120/782], Loss: 1.2900
# Epoch [4/19], Step [140/782], Loss: 1.4275
# Epoch [4/19], Step [160/782], Loss: 1.2847
# Epoch [4/19], Step [180/782], Loss: 1.2239
# Epoch [4/19], Step [200/782], Loss: 1.2202
# Epoch [4/19], Step [220/782], Loss: 1.6397
# Epoch [4/19], Step [240/782], Loss: 1.6089
# Epoch [4/19], Step [260/782], Loss: 1.3539
# Epoch [4/19], Step [280/782], Loss: 1.2623
# Epoch [4/19], Step [300/782], Loss: 1.7237
# Epoch [4/19], Step [320/782], Loss: 1.1755
# Epoch [4/19], Step [340/782], Loss: 1.3245
# Epoch [4/19], Step [360/782], Loss: 1.6046
# Epoch [4/19], Step [380/782], Loss: 1.3903
# Epoch [4/19], Step [400/782], Loss: 1.2239
# Epoch [4/19], Step [420/782], Loss: 1.3539
# Epoch [4/19], Step [440/782], Loss: 1.6371
# Epoch [4/19], Step [460/782], Loss: 1.5986
# Epoch [4/19], Step [480/782], Loss: 1.5497
# Epoch [4/19], Step [500/782], Loss: 1.4096
# Epoch [4/19], Step [520/782], Loss: 1.5730
# Epoch [4/19], Step [540/782], Loss: 1.5707
# Epoch [4/19], Step [560/782], Loss: 1.4434
# Epoch [4/19], Step [580/782], Loss: 1.4863
# Epoch [4/19], Step [600/782], Loss: 1.4989
# Epoch [4/19], Step [620/782], Loss: 1.4179
# Epoch [4/19], Step [640/782], Loss: 1.1931
# Epoch [4/19], Step [660/782], Loss: 1.8005
# Epoch [4/19], Step [680/782], Loss: 1.6463
# Epoch [4/19], Step [700/782], Loss: 1.4306
# Epoch [4/19], Step [720/782], Loss: 1.3830
# Epoch [4/19], Step [740/782], Loss: 1.1003
# Epoch [4/19], Step [760/782], Loss: 1.2495
# Epoch [4/19], Step [780/782], Loss: 1.7723
#
# train-loss: 0.0342, train-acc: 59.2420
# test loss: 0.0246, test acc: 68.2820
#
# Improvement-Detected, save-model
# Epoch 5
#
# Epoch [5/19], Step [0/782], Loss: 1.2314
# Epoch [5/19], Step [20/782], Loss: 1.1444
# Epoch [5/19], Step [40/782], Loss: 1.3906
# Epoch [5/19], Step [60/782], Loss: 1.2036
# Epoch [5/19], Step [80/782], Loss: 0.9745
# Epoch [5/19], Step [100/782], Loss: 1.0863
# Epoch [5/19], Step [120/782], Loss: 1.2351
# Epoch [5/19], Step [140/782], Loss: 1.7960
# Epoch [5/19], Step [160/782], Loss: 1.7647
# Epoch [5/19], Step [180/782], Loss: 1.4333
# Epoch [5/19], Step [200/782], Loss: 1.4002
# Epoch [5/19], Step [220/782], Loss: 1.4768
# Epoch [5/19], Step [240/782], Loss: 1.6016
# Epoch [5/19], Step [260/782], Loss: 1.3488
# Epoch [5/19], Step [280/782], Loss: 1.1644
# Epoch [5/19], Step [300/782], Loss: 1.2578
# Epoch [5/19], Step [320/782], Loss: 1.2907
# Epoch [5/19], Step [340/782], Loss: 1.5644
# Epoch [5/19], Step [360/782], Loss: 1.1574
# Epoch [5/19], Step [380/782], Loss: 1.3027
# Epoch [5/19], Step [400/782], Loss: 1.5046
# Epoch [5/19], Step [420/782], Loss: 1.5796
# Epoch [5/19], Step [440/782], Loss: 1.2878
# Epoch [5/19], Step [460/782], Loss: 1.4828
# Epoch [5/19], Step [480/782], Loss: 1.6262
# Epoch [5/19], Step [500/782], Loss: 1.4434
# Epoch [5/19], Step [520/782], Loss: 1.3929
# Epoch [5/19], Step [540/782], Loss: 1.1000
# Epoch [5/19], Step [560/782], Loss: 1.7362
# Epoch [5/19], Step [580/782], Loss: 1.1883
# Epoch [5/19], Step [600/782], Loss: 1.3918
# Epoch [5/19], Step [620/782], Loss: 1.4420
# Epoch [5/19], Step [640/782], Loss: 1.3862
# Epoch [5/19], Step [660/782], Loss: 1.1147
# Epoch [5/19], Step [680/782], Loss: 1.7502
# Epoch [5/19], Step [700/782], Loss: 1.1595
# Epoch [5/19], Step [720/782], Loss: 1.4774
# Epoch [5/19], Step [740/782], Loss: 1.6043
# Epoch [5/19], Step [760/782], Loss: 1.2033
# Epoch [5/19], Step [780/782], Loss: 1.3876
#
# train-loss: 0.0321, train-acc: 62.7360
# test loss: 0.0231, test acc: 71.0960
#
# Improvement-Detected, save-model
# Epoch 6
#
# Epoch [6/19], Step [0/782], Loss: 0.9633
# Epoch [6/19], Step [20/782], Loss: 1.1060
# Epoch [6/19], Step [40/782], Loss: 1.2427
# Epoch [6/19], Step [60/782], Loss: 0.9592
# Epoch [8/19], Step [680/782], Loss: 1.0636
# Epoch [8/19], Step [700/782], Loss: 1.2280
# Epoch [8/19], Step [720/782], Loss: 1.2209
# Epoch [8/19], Step [740/782], Loss: 0.9874
# Epoch [8/19], Step [760/782], Loss: 1.5259
# Epoch [8/19], Step [780/782], Loss: 1.5660
#
# train-loss: 0.0275, train-acc: 69.7560
# test loss: 0.0197, test acc: 78.6200
#
# Improvement-Detected, save-model
# Epoch 9
#
# Epoch [9/19], Step [0/782], Loss: 0.8165
# Epoch [9/19], Step [20/782], Loss: 0.8957
# Epoch [9/19], Step [40/782], Loss: 0.8759
# Epoch [9/19], Step [60/782], Loss: 1.3631
# Epoch [9/19], Step [80/782], Loss: 1.2470
# Epoch [9/19], Step [100/782], Loss: 1.1056
# Epoch [9/19], Step [120/782], Loss: 0.8397
# Epoch [9/19], Step [140/782], Loss: 0.9582
# Epoch [9/19], Step [160/782], Loss: 0.9794
# Epoch [9/19], Step [180/782], Loss: 1.0876
# Epoch [9/19], Step [200/782], Loss: 0.8676
# Epoch [9/19], Step [220/782], Loss: 1.2631
# Epoch [9/19], Step [240/782], Loss: 0.7577
# Epoch [9/19], Step [260/782], Loss: 1.3921
# Epoch [9/19], Step [280/782], Loss: 0.6392
# Epoch [9/19], Step [300/782], Loss: 0.9469
# Epoch [9/19], Step [320/782], Loss: 1.0409
# Epoch [9/19], Step [340/782], Loss: 1.0198
# Epoch [9/19], Step [360/782], Loss: 1.1396
# Epoch [9/19], Step [380/782], Loss: 1.0518
# Epoch [9/19], Step [400/782], Loss: 1.5937
# Epoch [9/19], Step [420/782], Loss: 1.0319
# Epoch [9/19], Step [440/782], Loss: 1.1855
# Epoch [9/19], Step [460/782], Loss: 1.1105
# Epoch [9/19], Step [480/782], Loss: 1.1599
# Epoch [9/19], Step [500/782], Loss: 0.7862
# Epoch [9/19], Step [520/782], Loss: 0.8808
# Epoch [9/19], Step [540/782], Loss: 1.1922
# Epoch [9/19], Step [560/782], Loss: 0.9207
# Epoch [9/19], Step [580/782], Loss: 0.9971
# Epoch [9/19], Step [600/782], Loss: 0.7252
# Epoch [9/19], Step [620/782], Loss: 1.0745
# Epoch [9/19], Step [640/782], Loss: 1.3498
# Epoch [9/19], Step [660/782], Loss: 1.1133
# Epoch [9/19], Step [680/782], Loss: 1.0621
# Epoch [9/19], Step [700/782], Loss: 1.3201
# Epoch [9/19], Step [720/782], Loss: 1.2780
# Epoch [9/19], Step [740/782], Loss: 0.9748
# Epoch [9/19], Step [760/782], Loss: 1.1495
# Epoch [9/19], Step [780/782], Loss: 1.0501
#
# train-loss: 0.0263, train-acc: 71.7280
# test loss: 0.0188, test acc: 79.7800
#
# Improvement-Detected, save-model
# Epoch 10
#
# Epoch [10/19], Step [0/782], Loss: 0.8243
# Epoch [10/19], Step [20/782], Loss: 1.1225
# Epoch [10/19], Step [40/782], Loss: 1.0560
# Epoch [10/19], Step [60/782], Loss: 0.7229
# Epoch [10/19], Step [80/782], Loss: 0.6123
# Epoch [10/19], Step [100/782], Loss: 0.6346
# Epoch [15/19], Step [460/782], Loss: 0.3834
# Epoch [15/19], Step [480/782], Loss: 0.2219
# Epoch [15/19], Step [500/782], Loss: 0.1858
# Epoch [15/19], Step [520/782], Loss: 0.1915
# Epoch [15/19], Step [540/782], Loss: 0.3624
# Epoch [15/19], Step [560/782], Loss: 0.3718
# Epoch [15/19], Step [580/782], Loss: 0.3805
# Epoch [15/19], Step [600/782], Loss: 0.4642
# Epoch [15/19], Step [620/782], Loss: 0.2707
# Epoch [15/19], Step [640/782], Loss: 0.4708
# Epoch [15/19], Step [660/782], Loss: 0.4302
# Epoch [15/19], Step [680/782], Loss: 0.2239
# Epoch [15/19], Step [700/782], Loss: 0.1839
# Epoch [15/19], Step [720/782], Loss: 0.3309
# Epoch [15/19], Step [740/782], Loss: 0.3474
# Epoch [15/19], Step [760/782], Loss: 0.2886
# Epoch [15/19], Step [780/782], Loss: 0.3028
#
# train-loss: 0.0192, train-acc: 89.4620
# test loss: 0.0133, test acc: 95.1600
#
# Improvement-Detected, save-model
# Epoch 16
#
# Epoch [16/19], Step [0/782], Loss: 0.2816
# Epoch [16/19], Step [20/782], Loss: 0.2803
# Epoch [16/19], Step [40/782], Loss: 0.1578
# Epoch [16/19], Step [60/782], Loss: 0.4516
# Epoch [16/19], Step [80/782], Loss: 0.3194
# Epoch [16/19], Step [100/782], Loss: 0.4187
# Epoch [16/19], Step [120/782], Loss: 0.2681
# Epoch [16/19], Step [140/782], Loss: 0.3895
# Epoch [16/19], Step [160/782], Loss: 0.1642
# Epoch [16/19], Step [180/782], Loss: 0.2008
# Epoch [16/19], Step [200/782], Loss: 0.2189
# Epoch [16/19], Step [220/782], Loss: 0.3134
# Epoch [16/19], Step [240/782], Loss: 0.2988
# Epoch [16/19], Step [260/782], Loss: 0.5196
# Epoch [16/19], Step [280/782], Loss: 0.3424
# Epoch [16/19], Step [300/782], Loss: 0.3411
# Epoch [16/19], Step [320/782], Loss: 0.3726
# Epoch [16/19], Step [340/782], Loss: 0.2059
# Epoch [16/19], Step [360/782], Loss: 0.6708
# Epoch [16/19], Step [380/782], Loss: 0.1387
# Epoch [16/19], Step [400/782], Loss: 0.3030
# Epoch [16/19], Step [420/782], Loss: 0.2614
# Epoch [16/19], Step [440/782], Loss: 0.3965
# Epoch [16/19], Step [460/782], Loss: 0.3822
# Epoch [16/19], Step [480/782], Loss: 0.3566
# Epoch [16/19], Step [500/782], Loss: 0.3344
# Epoch [16/19], Step [520/782], Loss: 0.3651
# Epoch [16/19], Step [540/782], Loss: 0.4197
# Epoch [16/19], Step [560/782], Loss: 0.2197
# Epoch [16/19], Step [580/782], Loss: 0.2637
# Epoch [16/19], Step [600/782], Loss: 0.2990
# Epoch [16/19], Step [620/782], Loss: 0.2703
# Epoch [16/19], Step [640/782], Loss: 0.3333
# Epoch [16/19], Step [660/782], Loss: 0.3363
# Epoch [16/19], Step [680/782], Loss: 0.3154
# Epoch [16/19], Step [700/782], Loss: 0.3687
# Epoch [16/19], Step [720/782], Loss: 0.2491
# Epoch [16/19], Step [740/782], Loss: 0.2892
# Epoch [19/19], Step [500/782], Loss: 0.1590
# Epoch [19/19], Step [520/782], Loss: 0.3877
# Epoch [19/19], Step [540/782], Loss: 0.2642
# Epoch [19/19], Step [560/782], Loss: 0.1235
# Epoch [19/19], Step [580/782], Loss: 0.1248
# Epoch [19/19], Step [600/782], Loss: 0.2789
# Epoch [19/19], Step [620/782], Loss: 0.1478
# Epoch [19/19], Step [640/782], Loss: 0.3949
# Epoch [19/19], Step [660/782], Loss: 0.2658
# Epoch [19/19], Step [680/782], Loss: 0.1416
# Epoch [19/19], Step [700/782], Loss: 0.2027
# Epoch [19/19], Step [720/782], Loss: 0.2207
# Epoch [19/19], Step [740/782], Loss: 0.4459
# Epoch [19/19], Step [760/782], Loss: 0.2061
# Epoch [19/19], Step [780/782], Loss: 0.1486
#
# train-loss: 0.0162, train-acc: 92.9580
# test loss: 0.0110, test acc: 97.6400
#
# Improvement-Detected, save-model

# %%
plt.title("Train-Test Accuracy")
plt.plot([x.cpu() for x in train_acces], label='Training acc')
plt.plot([x.cpu() for x in test_acces], label='Test acc')
plt.xlabel('num_epochs')
plt.ylabel('accuracy')
plt.legend(frameon=False)
plt.show()

# %%
plt.title("Train-Test Loss")
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Test loss')
plt.xlabel('num_epochs')
plt.ylabel('loss')
plt.legend(frameon=False)
plt.show()

# %%
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=2048, out_features=1024, bias=True)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Linear(in_features=512, out_features=256, bias=True)
#     (6): Dropout(p=0.2, inplace=False)
#     (7): Linear(in_features=256, out_features=128, bias=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=128, out_features=100, bias=True)
#   )
# )

# %%
num = 20
classes = data_sets['test'].classes
indices = list(range(len(data_sets['test'])))
np.random.shuffle(indices)
idx = indices[:num]
from torch.utils.data.sampler import SubsetRandomSampler
sampler = SubsetRandomSampler(idx)
loader = torch.utils.data.DataLoader(data_sets['test'], sampler=sampler, batch_size=num)
dataiter = iter(loader)
images, labels = next(dataiter)
#images, labels = dataiter.next()

# %%
def imshow(inp, title=None):

    inp = inp.cpu() if device else inp
    inp = inp.numpy().transpose((1, 2, 0))

    mean = np.array([0.4914, 0.4822, 0.4465])
    std = np.array([0.2023, 0.1994, 0.2010])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)

    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
plt.ion()

if use_cuda:
    images, labels = images.cuda(), labels.cuda()

outputs = model(images)
_, preds = torch.max(outputs.data, 1)
preds = preds.cpu().numpy() if use_cuda else preds.numpy()

images_so_far = 0
for i in range(num):
    images_so_far += 1
    ax = plt.subplot(2, 20//2, images_so_far)
    ax.axis('off')
    res = preds[i] == labels[i]
    ax.set_title('{}: {}'.format(classes[preds[i]], res))
    imshow(images[i])

plt.ioff()
